# %% [markdown]
# #

# %% [markdown]
# Datasets that are not that great -

# %% [markdown]
# - oregon_health_university_test_release - only valuable info is gender, handedness, and Dx

# %% [markdown]
# - brown_university_data_test_release - most of the data is "pending" including all ADHD info. Has IQ info, but no IQ measure

# %% [markdown]
# - Pittsburgh phenotypic - does not have any ADHD info, nor participants with ADHD, nor left-handed participants. Does have IQ info

# %% [markdown]
# Notes to look for within good datasets -

# %% [markdown]
# - Check for -999 - see if there is a correlation between no diagnosis and the -999 values, fill them in with appropriate replacements (usually from key)

# %% [markdown]
# - Not all good datasets have IQ information (but most do)

# %% [markdown]
# - Compare ADHD measures used - see if we can use the actual values (Inattentive, H\I) in presentation

# %% [markdown]
# To do -

# %% [markdown]
# - Figure out correlated values (aka are we going to use IQ or the ADHD and IQ score breakdowns? Handedness?)

# %% [markdown]
# - Check ADHD and IQ measures (determines also whether we can use the measures)

# %% [markdown]
# FOR SETH - It would be cool to see the correlation between secondary diagnosis and ADHD. Aka, we 0 = no 2nd dx and 1 = yes 2nd dx, and then use that in the correlation map (and potentially the other algorithms or visuals?)

# %% [markdown]
# Add in the ADHD Index, Inattentive, Hyper Impulsive columns, and take out IQ measure

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=46ff4eb8-17c9-47ac-87e1-b82fb356f236' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
